# %% [markdown]
# 3장 2강 : 메핑 및 집합 자료구조

# %% [markdown]
# 1. 딕셔너리(Dictionary) 자료구조

# %%
- key - Value 쌍 구조
- Key : Value를 찾기 위한 키워드, 중복 x, 리스트는 사용 불가

- Value : Key로 찾는 값, 중복 o

- {"키": 값}

-추가(CREATE) : 없는 키이름으로 값을 대입하면 추가
-조회(READ): ['키 이름']
    - keys() : 모든 키를 담은 View, 읽기 전용
    - values() : 모든 값을 담은 View, 읽기 전용
    - items(): (키, 값) 목록을 담은 View
# Out:
#   Cell In[5], line 1
#     - key - Value 쌍 구조
#                   ^
# SyntaxError: invalid syntax

# %%
user = {"email": "test@test.org",
"password": 1234, 
"namw":"김철수"}

# %%
user['mobile'] = "010-3000-2000"

user
# Out:
# {'email': 'test@test.org',
#  'password': 1234,
#  'namw': '김철수',
#  'mobile': '010-3000-2000'}

# %%
user.keys()
# Out:
# dict_keys(['email', 'password', 'namw', 'mobile'])

# %%
user.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 user. values()
#
# NameError: name 'user' is not defined
