# %%
print("hello,world")
# Out:
# Running cells with 'ax1-1 (3.13.x) (Python 3.13.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/jhc89/Documents/AX1-1/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print("hello,world")
# Out:
# Running cells with 'ax1-1 (3.13.x) (Python 3.13.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/jhc89/Documents/AX1-1/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print("hello,world")
# Out:
# hello,world

# %%
user_age = 20
product_price = 5000

# %%
user_age = 20

# %%
product_price = 5000

# %%
money = 20

# %%
money = money + 5000

# %%
x = 100
print(type(x))   # <class 'int'>

x = "hello"
print(type(x))   # <class 'str'>
# Out:
# <class 'int'>
# <class 'str'>
