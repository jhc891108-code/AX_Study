# %% [markdown]
# 2장 2강 : 기본 자료형과 형변환

# %% [markdown]
# 0. 주석(comment)
#
# 코드 상에 설명을 추가할때 사용, 인터프리터가 해석이 되지가 않는다.
#
# #:한줄 주석
# """...""": 여려줄 주석
# 코드 실행 : 인터프리터가 해석을 하지 않으므로 코드 실행을 배제할 수 있음

# %%
# 코드 설명
"""
한줄
두줄
세줄
"""

# %% [markdown]
# 1. 파이썬의 기본 자료형 (Pimitive Data Types)
#
# 자료: 연산에 필요한 값(데이터)
# 자료형: 값의 유형(데이터 종류)
#
# 숫자형: 정수형(int, 10, 20, ...)
# 논리형: 참(True), 거짓(False)
# 문자형
# 값 없음()

# %%
time = "10시"
if time, isdigit():
    int(time) + 1
# Out:
#   Cell In[7], line 2
#     if time, isdigit():
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 5 거짓으로 인식하는 값

# %%
0, "",[], None

# %%
messare = "1"
if messare:
        print("있음")
# Out:
# 있음

# %%
type(messare)
# Out:
# str

# %%
resuit = bool(messare)

resuit, type(resuit)
# Out:
# (True, bool)
