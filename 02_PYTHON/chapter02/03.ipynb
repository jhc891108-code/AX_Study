# %% [markdown]
# # 1장 3강

# %%
print("hello")
# Out:
# hello

# %%
print("world")
# Out:
# world

# %%
print("everyoue")
# Out:
# everyoue

# %%
print(money)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(money)
#
# NameError: name 'money' is not defined

# %%
money = 5000

# %%
monev = monev + 2000
print(money)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 monev = monev + 2000
#       2 print(money)
#
# NameError: name 'monev' is not defined

# %%
momney = 5000
monev = monev + 2000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 momney = 5000
# ----> 2 monev = monev + 2000
#
# NameError: name 'monev' is not defined

# %%
money = 5000

# %%
money + money + 2000
# Out:
# 12000

# %%
money
# Out:
# 5000

# %%
money + money + 2000
# Out:
# 12000

# %%
money + money + 2000
print(money)
# Out:
# 5000

# %%
id(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 id(x)
#
# NameError: name 'x' is not defined

# %%
 y = x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y = x
#
# NameError: name 'x' is not defined

# %%
y = x
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 y = x
#       2 y
#
# NameError: name 'x' is not defined
