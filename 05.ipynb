# %%
age = 25
message = f"내 나이는 {age}입니다."
message
# Out:
# '내 나이는 25입니다.'

# %%
result = 10 + 3.14
print(result) 

print(int(result))
# Out:
# 13.14
# 13

# %%
count = 10
count *= 5
print(count)
# Out:
# 50

# %%
print("apple" < "banana")
# Out:
# True

# %%
menu_name = 'Americano'

# %%
menu_price = 4500

# %%
menu_name = 'Americano'
menu_price = 4500

# %%
print('상품: %s | 가격: %d원' % (menu_name, menu_price))
print(f'상품: {menu_name} | 가격: {menu_price}원')
# Out:
# 상품: Americano | 가격: 4500원
# 상품: Americano | 가격: 4500원

# %%
price = 15000
print(f'금액:{price:>8,}원')
# Out:
# 금액:  15,000원
